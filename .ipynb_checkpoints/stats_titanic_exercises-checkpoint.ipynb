# %% [markdown]
# # Titanic Data Set - Statistics Review
#
# [Variable Descriptions](https://www.kaggle.com/c/titanic/data).

# %%
import scipy as sp
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Describe the data. **
# - How big?
# - What are the columns and what do they mean?

# %%
df = pd.read_csv('titanic.csv')
df.shape
df.dtypes
data.head()
# Out:
# (891, 12)
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **What’s the average age of:**
#
# - Any Titanic passenger
# - A survivor
# - A non-surviving first-class passenger
# - Male survivors older than 30 from anywhere but Queenstown

# %%
avg_ages = pd.Series([df.Age.mean(),
                     df[df["Survived"] == 1].Age.mean(),
                    df[(df['Survived'] == 0) & (df['Pclass'] == 1)].Age.mean(),
                    df[(df['Sex'] == 'male') &
                       (df['Survived'] == 1) & 
                       (df['Age'] > 30) &
                       (df['Embarked'] != 'Q')].Age.mean()])
type(avg_ages)
avg_ages.index = ['All Passengers', 'Survivors', 'Non-Survivors, 1st', 'Male, Survivors, 30+, Not QT']
avg_ages
# Out:
# pandas.core.series.Series
# All Passengers                  29.699118
# Survivors                       28.343690
# Non-Survivors, 1st              43.695312
# Male, Survivors, 30+, Not QT    41.487805
# dtype: float64

# %% [markdown]
# **For the groups from the previous task, how far (in years) are the average ages from the median ages?**

# %%
median_ages = pd.Series([df.Age.median(),
                     df[df["Survived"] == 1].Age.median(),
                    df[(df['Survived'] == 0) & (df['Pclass'] == 1)].Age.median(),
                    df[(df['Sex'] == 'male') &
                       (df['Survived'] == 1) & 
                       (df['Age'] > 30) &
                       (df['Embarked'] != 'Q')].Age.median()])
median_ages.index = ['All Passengers', 'Survivors', 'Non-Survivors, 1st', 'Male, Survivors, 30+, Not QT']
diff_ages = median_ages - avg_ages
diff_ages
# Out:
# All Passengers                 -1.699118
# Survivors                      -0.343690
# Non-Survivors, 1st              1.554688
# Male, Survivors, 30+, Not QT   -3.487805
# dtype: float64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **What’s the most common:**
# - Passenger class
# - Port of Embarkation
# - Number of siblings or spouses aboard for survivors

# %%
df.Pclass.mode()
df.Embarked.mode()
df.SibSp.mode()
# Out:
# 0    3
# dtype: int64
# 0    S
# dtype: object
# 0    0
# dtype: int64

# %% [markdown]
# **Within what range of standard deviations from the mean (0-1, 1-2, 2-3) is the median ticket price? Is it above or below the mean?**

# %%
mu = df.Fare.mean()
sd = df.Fare.std()
med = df.Fare.median()
(med - mu) / sd # note that htis is the Z score
# Out:
# -0.3571902456652297

# %% [markdown]
# **How much more expensive was the 90th percentile ticket than the 5th percentile ticket? Are they the same class?**

# %%
ninetieth = df.Fare.quantile(q=.9)
tenth = df.Fare.quantile(q=.05)
ninetieth
tenth
ninetieth - tenth
# Out:
# 77.9583
# 7.225
# 70.7333

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **The highest average ticket price was paid by passengers from which port? Null ports don’t count.**

# %%
pd.pivot_table(df, index='Embarked')
# Out:
#                 Age       Fare     Parch  PassengerId    Pclass     SibSp  \
# Embarked
# C         30.814769  59.954144  0.363095   445.357143  1.886905  0.386905
# Q         28.089286  13.276030  0.168831   417.896104  2.909091  0.428571
# S         29.445397  27.079812  0.413043   449.527950  2.350932  0.571429
#
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# **What is the most common passenger class for each port?**

# %%
pd.pivot_table(df, index='Embarked', values='Pclass', aggfunc=stats.mode)
# Out:
#                 Pclass
# Embarked
# C          ([1], [85])
# Q          ([3], [72])
# S         ([3], [353])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **What fraction of surviving 1st-class males paid lower than double the overall median ticket price?**

# %%
df.Fare.median()
2 * df.Fare.median()
df1 = df[(df['Sex'] == 'male') & (df['Survived'] == 1) & (df['Pclass'] == 1)].Fare
df1.head()
stats.percentileofscore(df1, 2 * df.Fare.median(), kind='strict')
# Out:
# 14.4542
# 28.9084
# 23     35.5000
# 55     35.5000
# 97     63.3583
# 187    26.5500
# 209    31.0000
# Name: Fare, dtype: float64
# 24.444444444444443

# %% [markdown]
# **How much older/younger was the average surviving passenger with family members than the average non-surviving passenger without them?**

# %%
df_surv_wfam = df[(df['Survived'] == 1) & ((df['SibSp'] > 0) | (df['Parch'] > 0))].Age
df_surv_wfam.head()
df_surv_wfam.mean()
df_nsurv_wofam = df[(df['Survived'] != 1) & ((df['SibSp'] == 0) & (df['Parch'] == 0))].Age
df_nsurv_wofam.head()
df_nsurv_wofam.mean()
df_surv_wfam.mean() - df_nsurv_wofam.mean()
# Out:
# 1     38.0
# 3     35.0
# 8     27.0
# 9     14.0
# 10     4.0
# Name: Age, dtype: float64
# 25.526062500000002
# 4     35.0
# 5      NaN
# 6     54.0
# 12    20.0
# 14    14.0
# Name: Age, dtype: float64
# 32.41423357664234
# -6.888171076642337

# %% [markdown]
# **Display the relationship (i.e. make a plot) between survival rate and the quantile of the ticket price for 20 integer quantiles.**
# - To be clearer, what I want is for you to specify 20 quantiles, and for each of those quantiles divide the number of survivors in that quantile by the total number of people in that quantile. That’ll give you the survival rate in that quantile.
# - Then plot a line of the survival rate against the ticket fare quantiles.
# - Make sure you label your axes.

# %%
df_sorted = df.sort_values('Fare')
df_sorted
# Out:
#      PassengerId  Survived  Pclass  \
# 271          272         1       3
# 597          598         0       3
# 302          303         0       3
# 633          634         0       1
# 277          278         0       2
# 413          414         0       2
# 674          675         0       2
# 263          264         0       1
# 466          467         0       2
# 732          733         0       2
# 179          180         0       3
# 806          807         0       1
# 481          482         0       2
# 822          823         0       1
# 815          816         0       1
# 378          379         0       3
# 872          873         0       1
# 326          327         0       3
# 843          844         0       3
# 818          819         0       3
# 371          372         0       3
# 202          203         0       3
# 654          655         0       3
# 143          144         0       3
# 411          412         0       3
# 825          826         0       3
# 129          130         0       3
# 804          805         1       3
# 477          478         0       3
# 611          612         0       3
# ..           ...       ...     ...
# 31            32         1       1
# 708          709         1       1
# 498          499         0       1
# 305          306         1       1
# 297          298         0       1
# 609          610         1       1
# 332          333         0       1
# 268          269         1       1
# 856          857         1       1
# 318          319         1       1
# 779          780         1       1
# 730          731         1       1
# 689          690         1       1
# 377          378         0       1
# 527          528         0       1
# 700          701         1       1
# 380          381         1       1
# 557          558         0       1
# 716          717         1       1
# 118          119         0       1
# 299          300         1       1
# 742          743         1       1
# 311          312         1       1
# 27            28         0       1
# 88            89         1       1
# 438          439         0       1
# 341          342         1       1
# 737          738         1       1
# 258          259         1       1
# 679          680         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 271                       Tornquist, Mr. William Henry    male  25.00      0
# 597                                Johnson, Mr. Alfred    male  49.00      0
# 302                    Johnson, Mr. William Cahoone Jr    male  19.00      0
# 633                      Parr, Mr. William Henry Marsh    male    NaN      0
# 277                        Parkes, Mr. Francis "Frank"    male    NaN      0
# 413                     Cunningham, Mr. Alfred Fleming    male    NaN      0
# 674                         Watson, Mr. Ennis Hastings    male    NaN      0
# 263                              Harrison, Mr. William    male  40.00      0
# 466                              Campbell, Mr. William    male    NaN      0
# 732                               Knight, Mr. Robert J    male    NaN      0
# 179                                Leonard, Mr. Lionel    male  36.00      0
# 806                             Andrews, Mr. Thomas Jr    male  39.00      0
# 481                   Frost, Mr. Anthony Wood "Archie"    male    NaN      0
# 822                    Reuchlin, Jonkheer. John George    male  38.00      0
# 815                                   Fry, Mr. Richard    male    NaN      0
# 378                                Betros, Mr. Tannous    male  20.00      0
# 872                           Carlsson, Mr. Frans Olof    male  33.00      0
# 326                          Nysveen, Mr. Johan Hansen    male  61.00      0
# 843                         Lemberopolous, Mr. Peter L    male  34.50      0
# 818                   Holm, Mr. John Fredrik Alexander    male  43.00      0
# 371                          Wiklund, Mr. Jakob Alfred    male  18.00      1
# 202                         Johanson, Mr. Jakob Alfred    male  34.00      0
# 654                       Hegarty, Miss. Hanora "Nora"  female  18.00      0
# 143                                Burke, Mr. Jeremiah    male  19.00      0
# 411                                    Hart, Mr. Henry    male    NaN      0
# 825                                    Flynn, Mr. John    male    NaN      0
# 129                                 Ekstrom, Mr. Johan    male  45.00      0
# 804                            Hedman, Mr. Oskar Arvid    male  27.00      0
# 477                          Braund, Mr. Lewis Richard    male  29.00      1
# 611                              Jardin, Mr. Jose Neto    male    NaN      0
# ..                                                 ...     ...    ...    ...
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female    NaN      1
# 708                               Cleaver, Miss. Alice  female  22.00      0
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 305                     Allison, Master. Hudson Trevor    male   0.92      1
# 297                       Allison, Miss. Helen Loraine  female   2.00      1
# 609                          Shutes, Miss. Elizabeth W  female  40.00      0
# 332                          Graham, Mr. George Edward    male  38.00      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.00      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.00      1
# 318                           Wick, Miss. Mary Natalie  female  31.00      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.00      0
# 730                      Allen, Miss. Elisabeth Walton  female  29.00      0
# 689                  Madill, Miss. Georgette Alexandra  female  15.00      0
# 377                          Widener, Mr. Harry Elkins    male  27.00      0
# 527                                 Farthing, Mr. John    male    NaN      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00      1
# 380                              Bidois, Miss. Rosalie  female  42.00      0
# 557                                Robbins, Mr. Victor    male    NaN      0
# 716                      Endres, Miss. Caroline Louise  female  38.00      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.00      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00      0
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.00      2
# 311                         Ryerson, Miss. Emily Borie  female  18.00      2
# 27                      Fortune, Mr. Charles Alexander    male  19.00      3
# 88                          Fortune, Miss. Mabel Helen  female  23.00      3
# 438                                  Fortune, Mr. Mark    male  64.00      1
# 341                     Fortune, Miss. Alice Elizabeth  female  24.00      3
# 737                             Lesurer, Mr. Gustave J    male  35.00      0
# 258                                   Ward, Miss. Anna  female  35.00      0
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.00      0
#
#      Parch              Ticket      Fare            Cabin Embarked
# 271      0                LINE    0.0000              NaN        S
# 597      0                LINE    0.0000              NaN        S
# 302      0                LINE    0.0000              NaN        S
# 633      0              112052    0.0000              NaN        S
# 277      0              239853    0.0000              NaN        S
# 413      0              239853    0.0000              NaN        S
# 674      0              239856    0.0000              NaN        S
# 263      0              112059    0.0000              B94        S
# 466      0              239853    0.0000              NaN        S
# 732      0              239855    0.0000              NaN        S
# 179      0                LINE    0.0000              NaN        S
# 806      0              112050    0.0000              A36        S
# 481      0              239854    0.0000              NaN        S
# 822      0               19972    0.0000              NaN        S
# 815      0              112058    0.0000             B102        S
# 378      0                2648    4.0125              NaN        C
# 872      0                 695    5.0000      B51 B53 B55        S
# 326      0              345364    6.2375              NaN        S
# 843      0                2683    6.4375              NaN        C
# 818      0              C 7075    6.4500              NaN        S
# 371      0             3101267    6.4958              NaN        S
# 202      0             3101264    6.4958              NaN        S
# 654      0              365226    6.7500              NaN        Q
# 143      0              365222    6.7500              NaN        Q
# 411      0              394140    6.8583              NaN        Q
# 825      0              368323    6.9500              NaN        Q
# 129      0              347061    6.9750              NaN        S
# 804      0              347089    6.9750              NaN        S
# 477      0                3460    7.0458              NaN        S
# 611      0  SOTON/O.Q. 3101305    7.0500              NaN        S
# ..     ...                 ...       ...              ...      ...
# 31       0            PC 17569  146.5208              B78        C
# 708      0              113781  151.5500              NaN        S
# 498      2              113781  151.5500          C22 C26        S
# 305      2              113781  151.5500          C22 C26        S
# 297      2              113781  151.5500          C22 C26        S
# 609      0            PC 17582  153.4625             C125        S
# 332      1            PC 17582  153.4625              C91        S
# 268      1            PC 17582  153.4625             C125        S
# 856      1               36928  164.8667              NaN        S
# 318      2               36928  164.8667               C7        S
# 779      1               24160  211.3375               B3        S
# 730      0               24160  211.3375               B5        S
# 689      1               24160  211.3375               B5        S
# 377      2              113503  211.5000              C82        C
# 527      0            PC 17483  221.7792              C95        S
# 700      0            PC 17757  227.5250          C62 C64        C
# 380      0            PC 17757  227.5250              NaN        C
# 557      0            PC 17757  227.5250              NaN        C
# 716      0            PC 17757  227.5250              C45        C
# 118      1            PC 17558  247.5208          B58 B60        C
# 299      1            PC 17558  247.5208          B58 B60        C
# 742      2            PC 17608  262.3750  B57 B59 B63 B66        C
# 311      2            PC 17608  262.3750  B57 B59 B63 B66        C
# 27       2               19950  263.0000      C23 C25 C27        S
# 88       2               19950  263.0000      C23 C25 C27        S
# 438      4               19950  263.0000      C23 C25 C27        S
# 341      2               19950  263.0000      C23 C25 C27        S
# 737      0            PC 17755  512.3292             B101        C
# 258      0            PC 17755  512.3292              NaN        C
# 679      1            PC 17755  512.3292      B51 B53 B55        C
#
# [891 rows x 12 columns]

# %%
total_surv = df.Survived.sum()
total_surv
fares = []
surv = []
df_sorted = df.sort_values('Fare')
for qnt in range(20):
    qnt = qnt/20 + 0.05
    last_fare_qnt= df_sorted.Fare.quantile(q=qnt - 0.05)  
    fare_qnt = df_sorted.Fare.quantile(q=qnt)  

    last_total = len(df_sorted[df_sorted['Fare'] <= last_fare_qnt])
    new_total =  len(df_sorted[df_sorted['Fare'] <= fare_qnt])
    total_in_qnt = new_total - last_total
   
    last_survived =  df_sorted[df_sorted['Fare'] <= last_fare_qnt].Survived.sum()
    new_survived = df_sorted[df_sorted['Fare'] <= fare_qnt].Survived.sum()
    survived_in_qnt = new_survived - last_survived
    
    surv_in_qnt_pct = survived_in_qnt / total_in_qnt
  
    
    print ("{0:.2f}".format(qnt), fare_qnt, last_survived, new_survived, survived_in_qnt, last_total, new_total, 
          total_in_qnt, surv_in_qnt_pct)
    
    #print("{0:.2f}".format(qnt), fare_qnt, surv_in_qnt_pct)
    fares.append(fare_qnt)
    surv.append(surv_in_qnt_pct)

#plot_data    
plt.figure(figsize=(17,5))
plt.plot(fares, surv)
plt.xlabel("fare")
plt.ylabel("survival rate")

plt.show()
# Out:
# 342
# 0.05 7.225 1 6 5 15 55 40 0.125
# 0.10 7.55 6 13 7 55 92 37 0.1891891891891892
# 0.15 7.75 13 29 16 92 140 48 0.3333333333333333
# 0.20 7.8542 29 39 10 140 179 39 0.2564102564102564
# 0.25 7.9104 39 44 5 179 223 44 0.11363636363636363
# 0.30 8.05 44 58 14 223 285 62 0.22580645161290322
# 0.35 9.0 58 62 4 285 313 28 0.14285714285714285
# 0.40 10.5 62 76 14 313 363 50 0.28
# 0.45 13.0 76 106 30 363 428 65 0.46153846153846156
# 0.50 14.4542 106 112 6 428 447 19 0.3157894736842105
# 0.55 16.1 112 130 18 447 494 47 0.3829787234042553
# 0.60 21.67920000000004 130 149 19 494 535 41 0.4634146341463415
# 0.65 26.0 149 177 28 535 596 61 0.45901639344262296
# 0.70 27.0 177 195 18 596 624 28 0.6428571428571429
# 0.75 31.0 195 213 18 624 669 45 0.4
# 0.80 39.6875 213 229 16 669 715 46 0.34782608695652173
# 0.85 56.4958 229 253 24 715 762 47 0.5106382978723404
# 0.90 77.9583 253 276 23 762 804 42 0.5476190476190477
# 0.95 112.07915 276 308 32 804 846 42 0.7619047619047619
# 1.00 512.3292 308 342 34 846 891 45 0.7555555555555555
# Text(0.5,0,'fare')
# Text(0,0.5,'survival rate')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **For each of the following characteristics, find the median in the data:**
# - Age
# - Ticket price
# - Siblings/spouses
# - Parents/children

# %%
df.Age.median()
df.Fare.median()
df.SibSp.median()
df.Parch.median()
# Out:
# 28.0
# 14.4542
# 0.0
# 0.0

# %% [markdown]
# **If you were to use these medians to draw numerical boundaries separating survivors from non-survivors, which of these characteristics would be the best choice and why?**

# %%
df[df['Survived'] == 0].Age.median()
df[df['Survived'] == 1].Age.median()
df[df['Survived'] == 0].Fare.median()
df[df['Survived'] == 1].Fare.median()
df[df['Survived'] == 0].SibSp.median()
df[df['Survived'] == 1].SibSp.median()
df[df['Survived'] == 0].Parch.median()
df[df['Survived'] == 1].Parch.median()
# Out:
# 28.0
# 28.0
# 10.5
# 26.0
# 0.0
# 0.0
# 0.0
# 0.0

# %%
# video solutioin that shows the coding style of the solution provider a technique he calls creating
# predicate, which is a sort of subset of the main dataframe

# function takes a criteria that subsets or filters the df, then returns the number of survivors over total
def survival_ratio(predicate):
    series = df[predicate]
    return len(series[series['Survived'] == True]) / len(series)

# creates the series we will populate by simply giving a name, similar to what creating empty list
below_at_median = pd.Series(name='Surv. below/at the median')
above_median = pd.Series(name='Surv. above the median')

# we now pop the series by using a label and value (similar to a Dict)
below_at_median['Age'] = survival_ratio(df['Age'] <= df['Age'].median())
below_at_median['Ticket Price'] = survival_ratio(df['Fare'] <= df['Fare'].median())
below_at_median['Siblings/Spouses'] = survival_ratio(df['SibSp'] <= df['SibSp'].median())
below_at_median['Parents/Children'] = survival_ratio(df['Parch'] <= df['Parch'].median())

above_median['Age'] = survival_ratio(df['Age'] > df['Age'].median())
above_median['Ticket Price'] = survival_ratio(df['Fare'] > df['Fare'].median())
above_median['Siblings/Spouses'] = survival_ratio(df['SibSp'] > df['SibSp'].median())
above_median['Parents/Children'] = survival_ratio(df['Parch'] > df['Parch'].median())

# take the series and create our dataframe using series as rows and then transposing, add col of diff and display
survival_median = pd.DataFrame([below_at_median, above_median],
                               columns=['Age', 'Ticket Price', 'Siblings/Spouses', 'Parents/Children']).transpose()
survival_median['Surv. above - Surv. at/below'] = above_median - below_at_median
survival_median
# Out:
#                   Surv. below/at the median  Surv. above the median  \
# Age                                0.408840                0.403409
# Ticket Price                       0.250559                0.518018
# Siblings/Spouses                   0.345395                0.466431
# Parents/Children                   0.343658                0.511737
#
#                   Surv. above - Surv. at/below
# Age                                  -0.005431
# Ticket Price                          0.267459
# Siblings/Spouses                      0.121036
# Parents/Children                      0.168079

# %% [markdown]
# **Plot the distribution of passenger ages. Choose visually-meaningful bin sizes and label your axes.**

# %%
ax = df['Age'].hist(figsize=(9,6), bins=8)
ax.set_xlabel('Age')
ax.set_ylabel('Number of Passengers');

# %% [markdown]
# **Find the probability that:**
# - A passenger survived
# - A passenger was male
# - A passenger was female and had at least one sibling or spouse on board
# - A survivor was from Cherbourg
# - A passenger was less than 10 years old
# - A passenger was between 25 and 40 years old
# - A passenger was either younger than 20 years old or older than 50

# %%
df.head()
df[(df['Sex'] == 'female') & (df['SibSp'] > 0)]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 9             10         1       2
# 10            11         1       3
# 18            19         0       3
# 24            25         0       3
# 25            26         1       3
# 31            32         1       1
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 49            50         0       3
# 52            53         1       1
# 53            54         1       2
# 58            59         1       2
# 68            69         1       3
# 71            72         0       3
# 85            86         1       3
# 88            89         1       1
# 109          110         1       3
# 111          112         0       3
# 113          114         0       3
# 119          120         0       3
# 128          129         1       3
# 132          133         0       3
# 133          134         1       2
# 142          143         1       3
# 147          148         0       3
# ..           ...       ...     ...
# 670          671         1       2
# 678          679         0       3
# 700          701         1       1
# 726          727         1       2
# 729          730         0       3
# 736          737         0       3
# 742          743         1       1
# 750          751         1       2
# 754          755         1       2
# 763          764         1       1
# 765          766         1       1
# 774          775         1       2
# 781          782         1       1
# 792          793         0       3
# 799          800         0       3
# 801          802         1       2
# 809          810         1       1
# 813          814         0       3
# 820          821         1       1
# 830          831         1       3
# 835          836         1       1
# 849          850         1       1
# 852          853         0       3
# 854          855         0       2
# 856          857         1       1
# 863          864         0       3
# 866          867         1       2
# 871          872         1       1
# 874          875         1       2
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                         Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 58                        West, Miss. Constance Mirium  female   5.0      1
# 68                     Andersson, Miss. Erna Alexandra  female  17.0      4
# 71                          Goodwin, Miss. Lillian Amy  female  16.0      5
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 109                                Moran, Miss. Bertha  female   NaN      1
# 111                               Zabour, Miss. Hileni  female  14.5      1
# 113                            Jussila, Miss. Katriina  female  20.0      1
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 128                                  Peter, Miss. Anna  female   NaN      1
# 132     Robins, Mrs. Alexander A (Grace Charity Laury)  female  47.0      1
# 133      Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0      1
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.0      1
# 147                   Ford, Miss. Robina Maggie "Ruby"  female   9.0      2
# ..                                                 ...     ...   ...    ...
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0      1
# 678            Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0      1
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 726        Renouf, Mrs. Peter Henry (Lillian Jefferys)  female  30.0      3
# 729                      Ilmakangas, Miss. Pieta Sofia  female  25.0      1
# 736            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0      1
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 750                                  Wells, Miss. Joan  female   4.0      1
# 754                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 792                            Sage, Miss. Stella Anna  female   NaN      8
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 830            Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0      1
# 835                        Compton, Miss. Sara Rebecca  female  39.0      1
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN      1
# 852                            Boulos, Miss. Nourelain  female   9.0      1
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0      1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket      Fare            Cabin Embarked
# 1        0          PC 17599   71.2833              C85        C
# 3        0            113803   53.1000             C123        S
# 9        0            237736   30.0708              NaN        C
# 10       1           PP 9549   16.7000               G6        S
# 18       0            345763   18.0000              NaN        S
# 24       1            349909   21.0750              NaN        S
# 25       5            347077   31.3875              NaN        S
# 31       0          PC 17569  146.5208              B78        C
# 38       0            345764   18.0000              NaN        S
# 39       0              2651   11.2417              NaN        C
# 40       0              7546    9.4750              NaN        S
# 41       0             11668   21.0000              NaN        S
# 43       2     SC/Paris 2123   41.5792              NaN        C
# 49       0            349237   17.8000              NaN        S
# 52       0          PC 17572   76.7292              D33        C
# 53       0              2926   26.0000              NaN        S
# 58       2        C.A. 34651   27.7500              NaN        S
# 68       2           3101281    7.9250              NaN        S
# 71       2           CA 2144   46.9000              NaN        S
# 85       0           3101278   15.8500              NaN        S
# 88       2             19950  263.0000      C23 C25 C27        S
# 109      0            371110   24.1500              NaN        Q
# 111      0              2665   14.4542              NaN        C
# 113      0              4136    9.8250              NaN        S
# 119      2            347082   31.2750              NaN        S
# 128      1              2668   22.3583            F E69        C
# 132      0         A/5. 3337   14.5000              NaN        S
# 133      0            228414   26.0000              NaN        S
# 142      0  STON/O2. 3101279   15.8500              NaN        S
# 147      2        W./C. 6608   34.3750              NaN        S
# ..     ...               ...       ...              ...      ...
# 670      1             29750   39.0000              NaN        S
# 678      6           CA 2144   46.9000              NaN        S
# 700      0          PC 17757  227.5250          C62 C64        C
# 726      0             31027   21.0000              NaN        S
# 729      0  STON/O2. 3101271    7.9250              NaN        S
# 736      3        W./C. 6608   34.3750              NaN        S
# 742      2          PC 17608  262.3750  B57 B59 B63 B66        C
# 750      1             29103   23.0000              NaN        S
# 754      2            220845   65.0000              NaN        S
# 763      2            113760  120.0000          B96 B98        S
# 765      0             13502   77.9583              D11        S
# 774      3             29105   23.0000              NaN        S
# 781      0             17474   57.0000              B20        S
# 792      2          CA. 2343   69.5500              NaN        S
# 799      1            345773   24.1500              NaN        S
# 801      1        C.A. 31921   26.2500              NaN        S
# 809      0            113806   53.1000               E8        S
# 813      2            347082   31.2750              NaN        S
# 820      1             12749   93.5000              B69        S
# 830      0              2659   14.4542              NaN        C
# 835      1          PC 17756   83.1583              E49        C
# 849      0             17453   89.1042              C92        C
# 852      1              2678   15.2458              NaN        C
# 854      0            244252   26.0000              NaN        S
# 856      1             36928  164.8667              NaN        S
# 863      2          CA. 2343   69.5500              NaN        S
# 866      0     SC/PARIS 2149   13.8583              NaN        C
# 871      1             11751   52.5542              D35        S
# 874      0         P/PP 3381   24.0000              NaN        C
# 888      2        W./C. 6607   23.4500              NaN        S
#
# [140 rows x 12 columns]

# %%
def calc_prob(predicate):
    return len(df[predicate]) / len(df)
    

probs = pd.Series()
probs['Survived'] = calc_prob(df['Survived'] == 1)
probs['Male'] = calc_prob(df['Sex'] == 'male')
probs['Female with Sibling or Spouse'] = calc_prob((df['Sex'] == 'female') & (df['SibSp'] != 0))
probs['Survived and from Cherbourg'] = calc_prob((df['Survived'] == 1) & (df['Embarked'] == 'C'))
probs['Age less than 10'] = calc_prob(df['Age'] < 10)
probs['Age between 25 and 40'] = calc_prob((df['Age'] > 25) & (df['Age'] < 40))
probs['Age less than 20 and greater than 50'] = calc_prob((df['Age'] < 20) | (df['Age'] > 50))


probs
# Out:
# Survived                                0.383838
# Male                                    0.647587
# Female with Sibling or Spouse           0.157127
# Survived and from Cherbourg             0.104377
# Age less than 10                        0.069585
# Age between 25 and 40                   0.280584
# Age less than 20 and greater than 50    0.255892
# dtype: float64

# %% [markdown]
# **Knowing nothing else about the passengers aside from the survival rate of the population (see question above), if I choose 100 passengers at random from the passenger list, what’s the probability that exactly 42 passengers survive?**

# %%
stats.binom.pmf(k=42, n=100, p=probs['Survived'])
# Out:
# 0.061330411815167886

# %% [markdown]
# **What’s the probability that at least 42 of those 100 passengers survive?**

# %%
fortytwo_plus = 1 - stats.binom.cdf(k=41, n=100, p=probs['Survived'])
fortytwo_plus
# Out:
# 0.25940724207261701

# %% [markdown]
# **Take random samples of 100 passengers and find out how many you need before the fraction of those samples where at least 42 passengers survive matches the probability you calculated previously (within Δp≈0.05).**
#
# Answers will vary based on chosen seeds. What would happen if you drew every sample with the same seed?
#
# Plot the survival fraction vs the number of random samples.

# %%
surv_frac = []
samples = 0
fortytwo_or_more = 0
tol = 1
seed = 7
while tol > 0.05:
    samples += 1
    samp = df.Survived.sample(n=100, random_state=seed).sum()
    if samp >= 42:
        fortytwo_or_more += 1
    tol = abs(fortytwo_plus - fortytwo_or_more / samples)
    print(tol, samples, fortytwo_or_more / samples)    
    seed = seed + 7
    surv_frac.append(fortytwo_or_more / samples)
surv_frac = pd.Series(surv_frac)
ax = surv_frac.plot(y='cum surv frac', figsize=(16,5))
ax.set_xlabel("Number of samples")
ax.set_ylabel('survival fraction')
# Out:
# 0.259407242073 1 0.0
# 0.259407242073 2 0.0
# 0.259407242073 3 0.0
# 0.259407242073 4 0.0
# 0.0594072420726 5 0.2
# 0.092740575406 6 0.16666666666666666
# 0.116550099215 7 0.14285714285714285
# 0.134407242073 8 0.125
# 0.0371850198504 9 0.2222222222222222
# Text(0.5,0,'Number of samples')
# Text(0,0.5,'survival fraction')

# %% [markdown]
# **Is there a statistically significant difference between:**
# - The ages of male and female survivors?
# - The fares paid by passengers from Queenstown and the passengers from Cherbourg?
#
# **Use a 95% confidence level.**

# %%
age_male_survivors = df.Age[(df['Survived'] == 1) & (df['Sex'] == 'male')]
age_male_survivors.mean(), age_female_survivors.mean()
age_female_survivors = df.Age[(df['Survived'] == 1) & (df['Sex'] == 'female')]
fare_Q = df.Fare[df["Embarked"] == 'Q']
fare_C = df.Fare[df["Embarked"] == 'C']
fare_Q.mean(), fare_C.mean()
# Out:
# (27.276021505376345, 28.84771573604061)
# (13.276029870129872, 59.95414404761905)

# %%
stats.ttest_ind(age_male_survivors, age_female_survivors, equal_var=False, nan_policy='omit')
stats.ttest_ind(fare_Q, fare_C, equal_var=False, nan_policy='omit')
# Out:
# Ttest_indResult(statistic=-0.79089662277024664, pvalue=0.43018823932006878)
# Ttest_indResult(statistic=-6.9951971047186809, pvalue=4.5792033919567422e-11)

# %% [markdown]
# **Accompany your p-values with histograms showing the distributions of both compared populations.**

# %%
plt.subplot(2, 2, 1)
ax = age_male_survivors.hist(figsize=(6,6), bins=8)
ax.set_xlabel('Age')
ax.set_ylabel('Number of Male Suvivors')
plt.subplot(2, 2, 2)
ax = age_female_survivors.hist(figsize=(6,6), bins=8)
ax.set_xlabel('Age')
ax.set_ylabel('Number of Female Suvivors')
plt.subplot(2, 2, 3)
ax = fare_Q.hist(figsize=(6,6), bins=[0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550])
ax.set_xlabel('Fare')
ax.set_ylabel('Number Embarking in Queenstown')
plt.subplot(2, 2, 4)
ax = fare_C.hist(figsize=(6,6), bins=[0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550])
ax.set_xlabel('Fare')
ax.set_ylabel('Number Embarking in Cherbourg');

# %% [markdown]
# **Did survivors pay more for their tickets than those that did not? Use a 95% confidence level.**

# %%
fare_survivors = df.Fare[df['Survived'] == 1]
fare_nonsurvivors = df.Fare[df['Survived'] == 0]
fare_survivors.mean(), fare_nonsurvivors.mean()
two_sided = stats.ttest_ind(fare_survivors, fare_nonsurvivors, equal_var=False, nan_policy='omit')
# one sided test means we need to divide p value by 2 - still well below 0.05
print('t = ', two_sided.statistic)
print('1 sided p = ', two_sided.pvalue/2)
# Out:
# (48.39540760233917, 22.117886885245877)
# t =  6.83909925909
# 1 sided p =  1.34966617516e-11

# %% [markdown]
# **Did a given first-class passenger have fewer family members on board than a given third-class passenger? Use a 95% confidence level.**

# %%
#add a new column 'Family' equal to SibSp + Parch
df['Family'] = df.SibSp + df.Parch
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 27            28         0       1
# 28            29         1       3
# 29            30         0       3
# ..           ...       ...     ...
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# 866          867         1       2
# 867          868         0       1
# 868          869         0       3
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 12                      Saundercock, Mr. William Henry    male  20.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                                Rice, Master. Eugene    male   2.0      4
# 17                        Williams, Mr. Charles Eugene    male   NaN      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# 21                               Beesley, Mr. Lawrence    male  34.0      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 28                       O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                 Todoroff, Mr. Lalio    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 861                        Giles, Mr. Frederick Edward    male  21.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 864                             Gill, Mr. John William    male  24.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 866                       Duran y More, Miss. Asuncion  female  27.0      1
# 867               Roebling, Mr. Washington Augustus II    male  31.0      0
# 868                        van Melkebeke, Mr. Philemon    male   NaN      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
# 870                                  Balkic, Mr. Cerin    male  26.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 876                      Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                               Petroff, Mr. Nedelio    male  19.0      0
# 878                                 Laleff, Mr. Kristo    male   NaN      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 881                                 Markun, Mr. Johann    male  33.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket      Fare        Cabin Embarked  Family
# 0        0         A/5 21171    7.2500          NaN        S       1
# 1        0          PC 17599   71.2833          C85        C       1
# 2        0  STON/O2. 3101282    7.9250          NaN        S       0
# 3        0            113803   53.1000         C123        S       1
# 4        0            373450    8.0500          NaN        S       0
# 5        0            330877    8.4583          NaN        Q       0
# 6        0             17463   51.8625          E46        S       0
# 7        1            349909   21.0750          NaN        S       4
# 8        2            347742   11.1333          NaN        S       2
# 9        0            237736   30.0708          NaN        C       1
# 10       1           PP 9549   16.7000           G6        S       2
# 11       0            113783   26.5500         C103        S       0
# 12       0         A/5. 2151    8.0500          NaN        S       0
# 13       5            347082   31.2750          NaN        S       6
# 14       0            350406    7.8542          NaN        S       0
# 15       0            248706   16.0000          NaN        S       0
# 16       1            382652   29.1250          NaN        Q       5
# 17       0            244373   13.0000          NaN        S       0
# 18       0            345763   18.0000          NaN        S       1
# 19       0              2649    7.2250          NaN        C       0
# 20       0            239865   26.0000          NaN        S       0
# 21       0            248698   13.0000          D56        S       0
# 22       0            330923    8.0292          NaN        Q       0
# 23       0            113788   35.5000           A6        S       0
# 24       1            349909   21.0750          NaN        S       4
# 25       5            347077   31.3875          NaN        S       6
# 26       0              2631    7.2250          NaN        C       0
# 27       2             19950  263.0000  C23 C25 C27        S       5
# 28       0            330959    7.8792          NaN        Q       0
# 29       0            349216    7.8958          NaN        S       0
# ..     ...               ...       ...          ...      ...     ...
# 861      0             28134   11.5000          NaN        S       1
# 862      0             17466   25.9292          D17        S       0
# 863      2          CA. 2343   69.5500          NaN        S      10
# 864      0            233866   13.0000          NaN        S       0
# 865      0            236852   13.0000          NaN        S       0
# 866      0     SC/PARIS 2149   13.8583          NaN        C       1
# 867      0          PC 17590   50.4958          A24        S       0
# 868      0            345777    9.5000          NaN        S       0
# 869      1            347742   11.1333          NaN        S       2
# 870      0            349248    7.8958          NaN        S       0
# 871      1             11751   52.5542          D35        S       2
# 872      0               695    5.0000  B51 B53 B55        S       0
# 873      0            345765    9.0000          NaN        S       0
# 874      0         P/PP 3381   24.0000          NaN        C       1
# 875      0              2667    7.2250          NaN        C       0
# 876      0              7534    9.8458          NaN        S       0
# 877      0            349212    7.8958          NaN        S       0
# 878      0            349217    7.8958          NaN        S       0
# 879      1             11767   83.1583          C50        C       1
# 880      1            230433   26.0000          NaN        S       1
# 881      0            349257    7.8958          NaN        S       0
# 882      0              7552   10.5167          NaN        S       0
# 883      0  C.A./SOTON 34068   10.5000          NaN        S       0
# 884      0   SOTON/OQ 392076    7.0500          NaN        S       0
# 885      5            382652   29.1250          NaN        Q       5
# 886      0            211536   13.0000          NaN        S       0
# 887      0            112053   30.0000          B42        S       0
# 888      2        W./C. 6607   23.4500          NaN        S       3
# 889      0            111369   30.0000         C148        C       0
# 890      0            370376    7.7500          NaN        Q       0
#
# [891 rows x 13 columns]

# %%
family_first = df.Family[df['Pclass'] == 1]
family_third = df.Family[df['Pclass'] == 3]
family_first.mean() - family_third.mean()
#use one sided t-test, so divide p value by 2
two_sided_ttest = stats.ttest_ind(family_first, family_third, equal_var=False, nan_policy='omit')
print('t = ', two_sided_ttest.statistic)
print('one-sided p-value = ', two_sided_ttest.pvalue/2)
# Out:
# -0.2349984913630534
# t =  -2.07990757489
# one-sided p-value =  0.0189536928743
